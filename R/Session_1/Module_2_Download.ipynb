# %% [markdown]
# # Session 1--Rstudio and downloading (September 10th)
#
#
# ### Session 1: notes
#
# 1. Module 1 covers Rstudio basics
#     - [Link](https://github.com/corybaird/SPP_Data_Seminar/blob/main/R/Session_1/Module_1_Rstudio.ipynb)
# 2. Module 2 covers downloading
#     - Current page
# 3. Excercise to practice material covered in Modules 1 & 2
#     - [Link](https://github.com/corybaird/SPP_Data_Seminar/blob/main/R/Session_1/Session_1_Excercise.ipynb)
#
#
#
# # Module 2: Downloading data
#
#
#
#
# ### Module 2 notes
#
# There are 4 common ways to import/download data
#
# 1. Read files from your computer
#     - See R.1
#         - Covered last week
#
#
# 2. Read files using R library
#     - See 1.1 WDI library
#
#
#
# 3. Read files directly from websites
#     - Zip data (see 2.1)
#     - xlsx data (see 2.2)
#     - github data (see 2.3)
#
#
# 4. Scrape data
#     - HTML tables (See 3.1)

# %% [markdown]
# # Review

# %% [markdown]
# ## R.1 Import from csv file
#
# ### R.1.1 From same working directory as code

# %%
df = read.csv('vote.csv')
head(df,2)
# Out:
#   state vote income education age sex
# 1 AR    1     9     2         73  0
# 2 AR    1    11     2         24  0

# %% [markdown]
# ### R.1.2 From sub-directory

# %%
## 2.2 Read csv file in sub-folder
df_arrests = read.csv("Sub_folder/arrests.csv")
head(df_arrests,2)
# Out:
#   X       Murder Assault UrbanPop Rape
# 1 Alabama 13.2   236     58       21.2
# 2 Alaska  10.0   263     48       44.5

# %% [markdown]
# # 1. Download data using libraries

# %% [markdown]
# ## 1.1 WDI library

# %% [markdown]
# ### 1.1.A Install packages and import library
#
# - This is done in R in two steps:
#     1. install.packages("Package name") Downloads package
#     2. library(Package name) Imports package

# %%
# Step 1: install
install.packages('WDI')

# Step 2:
library(WDI)
# Out:
# also installing the dependency ‘RJSONIO’
#
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %% [markdown]
# ### 1.1.1 Import dplyr library

# %%
search_df = WDIsearch(string = "gender", field = "name") 
head(search_df,4)
# Out:
#      indicator
# [1,] 2.3_GIR.GPI
# [2,] 2.6_PCR.GPI
# [3,] 5.51.01.07.gender
# [4,] BI.EMP.PWRK.PB.FE.ZS
#      name
# [1,] Gender parity index for gross intake ratio in grade 1
# [2,] Gender parity index for primary completion rate
# [3,] Gender equality
# [4,] Public sector employment as a share of paid employment by gender (Female)

# %% [markdown]
# ### 1.1.2 Download data

# %%
wdi_df = WDI(indicator = "5.51.01.07.gender", country= c('AF'), start=2000)
head(wdi_df,3)
# Out:
#   iso2c country     5.51.01.07.gender year
# 1 AF    Afghanistan 1.00000           2020
# 2 AF    Afghanistan 0.66667           2019
# 3 AF    Afghanistan 0.66667           2018

# %% [markdown]
# # 2. Download from websites

# %% [markdown]
# ## 2.1 Zip data

# %% [markdown]
# ### 2.1.A Download and import libraries

# %%
#Step 1
#install.packages('downloader')
#install.packages('foreign')
#install.packages('dplyr')

# %%
#Step 2
library(foreign) #Imports dta files
library(dplyr) #Data manipulation
library(downloader) #Downloads files from the internet

# %% [markdown]
# ### 2.1.1. Download zip
#
# - Data: MXFLS data
#     - Website url: http://www.ennvih-mxfls.org/english/ennvih-1.html

# %%
#URL 
url = "http://www.ennvih-mxfls.org/english/assets/hh02dta_bc.zip"
#File name
file_name = "mxfls.zip"

# %%
# "Downloader" library--function: download.file()
download.file(url, file_name)

# %%
#Shows folders
list.dirs()
# Out:
# [1] "."                    "./.ipynb_checkpoints" "./hh02dta_bc"
# [4] "./Images"             "./Sub_folder"

# %% [markdown]
# ### 2.1.2 Show files in zip folder

# %%
unzip("mxfls.zip", list = TRUE)
# Out:
#   Name                    Length  Date
# 1 hh02dta_bc/c_conpor.dta 2834192 2004-12-20 19:18:00
# 2 hh02dta_bc/c_cv.dta     1730138 2004-12-20 19:18:00
# 3 hh02dta_bc/c_cvo.dta     406940 2004-12-20 19:18:00
# 4 hh02dta_bc/c_eh.dta      249060 2005-07-14 10:35:00
# 5 hh02dta_bc/c_ls.dta     3428996 2004-12-20 19:18:00
# 6 hh02dta_bc/c_ne.dta      103070 2004-12-20 19:18:00
# 7 hh02dta_bc/c_portad.dta  373398 2005-07-14 10:35:00
# 8 hh02dta_bc/c_rc.dta      440998 2004-12-20 19:18:00
# 9 hh02dta_bc/c_sp.dta     1116290 2005-07-14 10:35:00

# %% [markdown]
# ### 2.1.3 Unzip folder

# %%
unzip("mxfls.zip")

# %% [markdown]
# ### 2.1.4 Import data

# %%
df = read.dta("hh02dta_bc/c_ls.dta")

# %%
df %>% 
head(2)
# Out:
#   folio ls secuencia ls00 ls02_1 ls02_2 ls03_1 ls03_21 ls03_22 ls04 ... ls09
# 1 1000  1  1         1    1      37     NA     NA      NA      1    ... 1
# 2 1000  2  2         2    1      35     NA     NA      NA      3    ... 1
#   ls10 ls11 ls12 ls13_1 ls13_2 ls14 ls15_1 ls16 ls18
# 1 5    2    1     1     32000  3     6     3    NA
# 2 5    1    3    NA        NA  1    NA     3    NA

# %% [markdown]
# ## 2.2 Directly from url

# %% [markdown]
# ### 2.2.A Show files in directory

# %%
list.files()
# Out:
# [1] "hh02dta_bc"              "Images"
# [3] "Module_1_Rstudio.ipynb"  "Module_2_Download.ipynb"
# [5] "Module_2_Rstudio.ipynb"  "mxfls.zip"
# [7] "Sub_folder"              "vote.csv"

# %% [markdown]
# ### 2.2.1 Download

# %%
url = 'https://www.macrohistory.net/app/download/9834512569/JSTdatasetR5.xlsx?t=1623599312'
file_name = 'Macro.xlsx'
download.file(url, file_name)

# %%
list.files()
# Out:
# [1] "hh02dta_bc"              "Images"
# [3] "Macro.xlsx"              "Module_1_Rstudio.ipynb"
# [5] "Module_2_Download.ipynb" "Module_2_Rstudio.ipynb"
# [7] "mxfls.zip"               "Sub_folder"
# [9] "vote.csv"

# %%
df_macro = read_excel('macro.xlsx', sheet=2) #Reads second sheet
head(df_macro)
# Out:
#   year country   iso ifs pop  rgdpmad  rgdppc   rconpc   gdp    iy        ...
# 1 1870 Australia AUS 193 1775 3273.239 13.83616 21.44973 208.78 0.1092656 ...
# 2 1871 Australia AUS 193 1675 3298.507 13.93686 19.93080 211.56 0.1045791 ...
# 3 1872 Australia AUS 193 1722 3553.426 15.04425 21.08501 227.40 0.1304380 ...
# 4 1873 Australia AUS 193 1769 3823.629 16.21944 23.25491 266.54 0.1249862 ...
# 5 1874 Australia AUS 193 1822 3834.797 16.26823 23.45805 287.58 0.1419599 ...
# 6 1875 Australia AUS 193 1874 4138.207 17.59211 25.66951 300.74 0.1605640 ...
#   eq_capgain  eq_dp      eq_capgain_interp eq_tr_interp eq_dp_interp bond_rate
# 1 -0.07004543 0.07141703 NA                NA           NA           0.04911817
# 2  0.04165363 0.06546638 NA                NA           NA           0.04844633
# 3  0.10894547 0.06299735 NA                NA           NA           0.04737350
# 4  0.08308647 0.06448419 NA                NA           NA           0.04671958
# 5  0.11938886 0.06350296 NA                NA           NA           0.04653317
# 6  0.05705873 0.06364298 NA                NA           NA           0.04507325
#   eq_div_rtn capital_tr risky_tr safe_tr
# 1 0.06641459 NA         NA       NA
# 2 0.06819329 NA         NA       NA
# 3 0.06986062 NA         NA       NA
# 4 0.06984195 NA         NA       NA
# 5 0.07108451 NA         NA       NA
# 6 0.06727437 NA         NA       NA

# %% [markdown]
# ## 2.3 Download from github
#
# - https://github.com/nytimes/covid-19-data/blob/master/excess-deaths/deaths.csv
# - View raw file
# - Copy url from raw file

# %%
url = 'https://raw.githubusercontent.com/nytimes/covid-19-data/master/excess-deaths/deaths.csv'
df_covid = read.csv(url)
head(df_covid,3)
# Out:
#   country placename frequency start_date end_date   year month week deaths
# 1 Austria           weekly    2020-01-06 2020-01-12 2020 1     2    1702
# 2 Austria           weekly    2020-01-13 2020-01-19 2020 1     3    1797
# 3 Austria           weekly    2020-01-20 2020-01-26 2020 1     4    1779
#   expected_deaths excess_deaths baseline
# 1 1806            -104          2015-2019 historical data
# 2 1819             -22          2015-2019 historical data
# 3 1831             -52          2015-2019 historical data

# %% [markdown]
# # 3. Scraping

# %% [markdown]
# ## 3.1 Read html table

# %% [markdown]
# ### 3.1.A Import library

# %%
# Step 1
#install.packages('rvest')
# Step 2
library(rvest)

# %% [markdown]
# ### 3.1.1 Download webpage -- XML format

# %%
url =  "https://en.wikipedia.org/wiki/List_of_current_United_States_governors"
file = read_html(url)
file
# Out:
# {xml_document}
# <html class="client-nojs" lang="en" dir="ltr">
# [1] <head>\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8 ...
# [2] <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject  ...

# %% [markdown]
# ### 3.1.2 Extract tables

# %%
tables = html_nodes(file, "table")
#tables

# %% [markdown]
# ### 3.1.3 Table -> Dataframe

# %%
table1 = html_table(tables[2], fill = TRUE)
table1
# Out:
# [[1]]
#    Democratic (23) \n  Republican (27) Democratic (23) \n  Republican (27)
# 1                                State                            Portrait
# 2                              Alabama
# 3                               Alaska
# 4                              Arizona
# 5                             Arkansas
# 6                           California
# 7                             Colorado
# 8                          Connecticut
# 9                             Delaware
# 10                             Florida
# 11                             Georgia
# 12                              Hawaii
# 13                               Idaho
# 14                            Illinois
# 15                             Indiana
# 16                                Iowa
# 17                              Kansas
# 18                            Kentucky
# 19                           Louisiana
# 20                               Maine
# 21                            Maryland
# 22                       Massachusetts
# 23                            Michigan
# 24                           Minnesota
# 25                         Mississippi
# 26                            Missouri
# 27                             Montana
# 28                            Nebraska
# 29                              Nevada
# 30                       New Hampshire
# 31                          New Jersey
# 32                          New Mexico
# 33                            New York
# 34                      North Carolina
# 35                        North Dakota
# 36                                Ohio
# 37                            Oklahoma
# 38                              Oregon
# 39                        Pennsylvania
# 40                        Rhode Island
# 41                      South Carolina
# 42                        South Dakota
# 43                           Tennessee
# 44                               Texas
# 45                                Utah
# 46                             Vermont
# 47                            Virginia
# 48                          Washington
# 49                       West Virginia
# 50                           Wisconsin
# 51                             Wyoming
#    Democratic (23) \n  Republican (27) Democratic (23) \n  Republican (27)
# 1                             Governor                               Party
# 2                             Kay Ivey
# 3                        Mike Dunleavy
# 4                           Doug Ducey
# 5                       Asa Hutchinson
# 6                         Gavin Newsom
# 7                          Jared Polis
# 8                           Ned Lamont
# 9                          John Carney
# 10                        Ron DeSantis
# 11                          Brian Kemp
# 12                           David Ige
# 13                         Brad Little
# 14                      J. B. Pritzker
# 15                        Eric Holcomb
# 16                        Kim Reynolds
# 17                         Laura Kelly
# 18                        Andy Beshear
# 19                    John Bel Edwards
# 20                         Janet Mills
# 21                         Larry Hogan
# 22                       Charlie Baker
# 23                    Gretchen Whitmer
# 24                            Tim Walz
# 25                         Tate Reeves
# 26                         Mike Parson
# 27                      Greg Gianforte
# 28                       Pete Ricketts
# 29                       Steve Sisolak
# 30                        Chris Sununu
# 31                         Phil Murphy
# 32              Michelle Lujan Grisham
# 33                        Kathy Hochul
# 34                          Roy Cooper
# 35                         Doug Burgum
# 36                         Mike DeWine
# 37                         Kevin Stitt
# 38                          Kate Brown
# 39                            Tom Wolf
# 40                        Daniel McKee
# 41                      Henry McMaster
# 42                         Kristi Noem
# 43                            Bill Lee
# 44                         Greg Abbott
# 45                         Spencer Cox
# 46                          Phil Scott
# 47                       Ralph Northam
# 48                          Jay Inslee
# 49                         Jim Justice
# 50                          Tony Evers
# 51                         Mark Gordon
#    Democratic (23) \n  Republican (27)      Democratic (23) \n  Republican (27)
# 1                                Party                                     Born
# 2                           Republican   (1944-10-15) October 15, 1944 (age 76)
# 3                           Republican        (1961-05-05) May 5, 1961 (age 60)
# 4                           Republican      (1964-04-09) April 9, 1964 (age 57)
# 5                           Republican   (1950-12-03) December 3, 1950 (age 70)
# 6                           Democratic   (1967-10-10) October 10, 1967 (age 53)
# 7                           Democratic       (1975-05-12) May 12, 1975 (age 46)
# 8                           Democratic    (1954-01-03) January 3, 1954 (age 67)
# 9                           Democratic       (1956-05-20) May 20, 1956 (age 65)
# 10                          Republican (1978-09-14) September 14, 1978 (age 42)
# 11                          Republican   (1963-11-02) November 2, 1963 (age 57)
# 12                          Democratic   (1957-01-15) January 15, 1957 (age 64)
# 13                          Republican  (1954-02-15) February 15, 1954 (age 67)
# 14                          Democratic   (1965-01-19) January 19, 1965 (age 56)
# 15                          Republican        (1968-05-02) May 2, 1968 (age 53)
# 16                          Republican     (1959-08-04) August 4, 1959 (age 62)
# 17                          Democratic   (1950-01-24) January 24, 1950 (age 71)
# 18                          Democratic  (1977-11-29) November 29, 1977 (age 43)
# 19                          Democratic (1966-09-16) September 16, 1966 (age 54)
# 20                          Democratic  (1947-12-30) December 30, 1947 (age 73)
# 38                   February 18, 2015                  2023 (term limits)
# 39                    January 20, 2015                  2023 (term limits)
# 40                       March 2, 2021                                2023
# 41                    January 24, 2017                                2023
# 42                     January 5, 2019                                2023
# 43                    January 19, 2019                                2023
# 44                    January 20, 2015                                2023
# 45                     January 4, 2021                                2025
# 46                     January 5, 2017                                2023
# 47                    January 13, 2018                  2022 (term limits)
# 48                    January 16, 2013                                2025
# 49                    January 16, 2017                  2025 (term limits)
# 50                     January 7, 2019                                2023
# 51                     January 7, 2019                                2023
#    Democratic (23) \n  Republican (27) Democratic (23) \n  Republican (27)
# 1                       Past governors                                  NA
# 2                                 List                                  NA
# 3                                 List                                  NA
# 4                                 List                                  NA
# 5                                 List                                  NA
# 6                                 List                                  NA
# 7                                 List                                  NA
# 8                                 List                                  NA
# 9                                 List                                  NA
# 10                                List                                  NA
# 11                                List                                  NA
# 12                                List                                  NA
# 13                                List                                  NA
# 14                                List                                  NA
# 15                                List                                  NA
# 16                                List                                  NA
# 17                                List                                  NA
# 18                                List                                  NA
# 19                                List                                  NA
# 20                                List                                  NA
# 21                                List                                  NA
# 22                                List                                  NA
# 23                                List                                  NA
# 24                                List                                  NA
# 25                                List                                  NA
# 26                                List                                  NA
# 27                                List                                  NA
# 28                                List                                  NA
# 29                                List                                  NA
# 30                                List                                  NA
# 31                                List                                  NA
# 32                                List                                  NA
# 33                                List                                  NA
# 34                                List                                  NA
# 35                                List                                  NA
# 36                                List                                  NA
# 37                                List                                  NA
# 38                                List                                  NA
# 39                                List                                  NA
# 40                                List                                  NA
# 41                                List                                  NA
# 42                                List                                  NA
# 43                                List                                  NA
# 44                                List                                  NA
# 45                                List                                  NA
# 46                                List                                  NA
# 47                                List                                  NA
# 48                                List                                  NA
# 49                                List                                  NA
# 50                                List                                  NA
# 51                                List                                  NA

# %% [markdown]
# # Appendix: Reading stata files
#
# ## A.1 dta files

# %%
#url = 'https://github.com/corybaird/PLCY_611_Public/blob/f4b9cc3ad04f174a1de78f13fa3a2b500fbe700d/Sessions/Session_1/session1.dta?raw=true'
#df = read.dta(url)
#head(df,2)

# %% [markdown]
# ## A.2 dta files (stata 13>=above)

# %%
install.packages('readstata13')
library(readstata13)
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
url = "https://github.com/corybaird/PLCY_611_Public/blob/main/Sessions/Session_1/session1.dta?raw=true"
df = read.dta13(url)
head(df,2)
# Out:
# Warning message in read.dta13(url):
# “
#    Factor codes of type double or float detected in variables
#
#    gov, region, urban, sex, nationality,
#    marital, reltohd, student, educatt1,
#    rsnnosrch, rsnolf, fteducatt, mteducatt
#
#    No labels have been assigned.
#    Set option 'nonint.factors = TRUE' to assign labels anyway.
# ”
#   hhid    indid     gov district subdistrict stratum region urban sex pn ...
# 1 1027101 102710101 21  3        1           1       2      1     2   1  ...
# 2 1027101 102710102 21  3        1           1       2      1     2   2  ...
#   crlfsr1 student educatt1 wealth    qwealth yrseduc rsnnosrch rsnolf fteducatt
# 1 1       0       3        -1.457183 1       9       NA        NA     2
# 2 0       1       2        -1.457183 1       9       NA         1     2
#   mteducatt
# 1 1
# 2 3
